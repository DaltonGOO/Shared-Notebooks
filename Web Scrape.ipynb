# %% [markdown]
# # Links
#
# ### Common Resources
# [Stackoverflow](https://stackoverflow.com/)
#
# [Python 3 Documentation](https://docs.python.org/3/library/)
#
# ### Python links
#
# [Extract links from webpage](https://pythonspot.com/extract-links-from-webpage-beautifulsoup/)
#
# [Links into a table](https://python-forum.io/Thread-How-to-get-hyperlinks-in-to-the-table-extracted-by-BeautifulSoup)
#
# [Stackoverflow](https://stackoverflow.com/)
#
# [Beautiful soup doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# [Counting Fregencies](https://programminghistorian.org/en/lessons/counting-frequencies)
#
# [Pandas tutorial 2 aggragation and grouping](https://data36.com/pandas-tutorial-2-aggregation-and-grouping/)
#
# [How to Connect Python to SQL Server using pyodbc](https://datatofish.com/how-to-connect-python-to-sql-server-using-pyodbc/)
#
# [Using Python Pandas dataframe to read and insert data to Microsoft SQL Server](https://tomaztsql.wordpress.com/2018/07/15/using-python-pandas-dataframe-to-read-and-insert-data-to-microsoft-sql-server/)
#
# [python-and-data-sql-server-as-a-data-source-for-python-applications](https://blogs.msdn.microsoft.com/cdndevs/2015/03/11/python-and-data-sql-server-as-a-data-source-for-python-applications/)
#
#
# ### My YouTube vids
#
#
#
#
# ### Markdown links
# [Markdown Cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# [Markdown Guide](https://www.markdownguide.org/)
#
# [Markdown Table Generator](https://www.tablesgenerator.com/markdown_tables)
#
#
# ### Code

# %%
from bs4 import BeautifulSoup
import urllib
import re
from docx import Document
from docx.shared import Inches
import pandas as pd

# %%
r = urllib.request.urlopen('https://bimchapters.blogspot.com/').read()
soup = BeautifulSoup(r,"lxml")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title
# Out:
# <title>BIM Chapters</title>

# %%
soup.a
# Out:
# <a name="5545266689102009819"></a>

# %%
#soup.find_all('a')

# %%
#print(soup.get_text())

# %%
for link in soup.find_all('a'): 
    (link.get('href'))
    print (link.get('href'))
# Out:
# None
# https://bimchapters.blogspot.com/2019/04/living-wall-example-in-revit.html
# https://1.bp.blogspot.com/-SqhP8FJgXqw/XMBD-JNF34I/AAAAAAAAVGA/uzlYdW2rtCION28QuKobX0TnLlCRiqZ9ACLcBGAs/s1600/Enscape_2019-04-23-17-48-12.png
# https://bimchapters.blogspot.com/2019/04/living-wall-example-in-revit.html#more
# https://www.blogger.com/profile/02666030766868750338
# https://bimchapters.blogspot.com/2019/04/living-wall-example-in-revit.html
# https://bimchapters.blogspot.com/2019/04/living-wall-example-in-revit.html#comment-form
# https://www.blogger.com/post-edit.g?blogID=8012622541860735055&postID=5545266689102009819&from=pencil
# https://www.blogger.com/share-post.g?blogID=8012622541860735055&postID=5545266689102009819&target=email
# https://www.blogger.com/share-post.g?blogID=8012622541860735055&postID=5545266689102009819&target=blog
# https://www.blogger.com/share-post.g?blogID=8012622541860735055&postID=5545266689102009819&target=twitter
# ...
